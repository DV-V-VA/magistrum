# %% [markdown]
# # RAG With llama-index  + Milvus + Qwen - Part 2
#
# References
#
# - https://studio.nebius.com/
# - https://docs.llamaindex.ai/en/stable/examples/vector_stores/MilvusIndexDemo/
# - https://docs.llamaindex.ai/en/stable/api_reference/storage/vector_store/milvus/?h=milvusvectorstore#llama_index.vector_stores.milvus.MilvusVectorStore

# %% [markdown]
# - 1) проверьте файл .env
# - 2) kernel - studio1

# %% [markdown]
# ## Step-1: Configuration

# %%
import os
from dotenv import load_dotenv
load_dotenv()

if os.getenv('NEBIUS_API_KEY'):
    print ("✅ Found NEBIUS_API_KEY in environment, using it")
else:
    raise ValueError("❌ NEBIUS_API_KEY not found in environment. Please set it in .env file before running this script.")
# Out:
# ✅ Found NEBIUS_API_KEY in environment, using it

# %%
! pip install -r requirements.txt
# Out:
# Ignoring appnope: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring cffi: markers 'implementation_name == "pypy"' don't match your environment
# Ignoring pycparser: markers 'implementation_name == "pypy"' don't match your environment
# Ignoring pywin32: markers 'platform_python_implementation != "PyPy" and sys_platform == "win32"' don't match your environment
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.6.1)
# Collecting aiohttp==3.12.15 (from -r requirements.txt (line 5))
#   Downloading aiohttp-3.12.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: aiosignal==1.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (1.4.0)
# Collecting aiosqlite==0.21.0 (from -r requirements.txt (line 9))
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types==0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.7.0)
# Collecting anyio==4.10.0 (from -r requirements.txt (line 13))
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting asttokens==3.0.0 (from -r requirements.txt (line 19))
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting attrs==25.3.0 (from -r requirements.txt (line 21))
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting banks==2.2.0 (from -r requirements.txt (line 23))
#   Downloading banks-2.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting beautifulsoup4==4.13.4 (from -r requirements.txt (line 25))
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting certifi==2025.8.3 (from -r requirements.txt (line 27))
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer==3.4.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 35)) (3.4.3)
# Collecting click==8.2.1 (from -r requirements.txt (line 37))
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting colorama==0.4.6 (from -r requirements.txt (line 41))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting comm==0.2.3 (from -r requirements.txt (line 47))
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting dataclasses-json==0.6.7 (from -r requirements.txt (line 49))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting debugpy==1.8.16 (from -r requirements.txt (line 51))
#   Downloading debugpy-1.8.16-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting decorator==5.2.1 (from -r requirements.txt (line 53))
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 55)) (0.7.1)
# Collecting deprecated==1.2.18 (from -r requirements.txt (line 57))
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting dirtyjson==1.0.8 (from -r requirements.txt (line 63))
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: distro==1.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 65)) (1.9.0)
# Collecting executing==2.2.0 (from -r requirements.txt (line 67))
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting filelock==3.18.0 (from -r requirements.txt (line 69))
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting filetype==1.2.0 (from -r requirements.txt (line 73))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting frozenlist==1.7.0 (from -r requirements.txt (line 75))
#   Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting fsspec==2025.7.0 (from -r requirements.txt (line 79))
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: greenlet==3.2.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 83)) (3.2.4)
# Collecting griffe==1.11.1 (from -r requirements.txt (line 85))
#   Downloading griffe-1.11.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting grpcio==1.74.0 (from -r requirements.txt (line 87))
#   Downloading grpcio-1.74.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: h11==0.16.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 89)) (0.16.0)
# Collecting hf-xet==1.1.7 (from -r requirements.txt (line 91))
#   Downloading hf_xet-1.1.7-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (703 bytes)
# Requirement already satisfied: httpcore==1.0.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 93)) (1.0.9)
# Requirement already satisfied: httpx==0.28.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 95)) (0.28.1)
# Collecting huggingface-hub==0.34.4 (from -r requirements.txt (line 100))
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 104)) (3.10)
# Collecting ipykernel==6.30.1 (from -r requirements.txt (line 110))
#   Downloading ipykernel-6.30.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting ipython==9.4.0 (from -r requirements.txt (line 111))
#   Downloading ipython-9.4.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting ipython-pygments-lexers==1.1.1 (from -r requirements.txt (line 113))
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi==0.19.2 (from -r requirements.txt (line 115))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: jinja2==3.1.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 117)) (3.1.6)
# Collecting jiter==0.10.0 (from -r requirements.txt (line 119))
#   Downloading jiter-0.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting joblib==1.5.1 (from -r requirements.txt (line 121))
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting jupyter-client==8.6.3 (from -r requirements.txt (line 123))
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-core==5.8.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 125)) (5.8.1)
# Collecting llama-cloud==0.1.35 (from -r requirements.txt (line 129))
#   Downloading llama_cloud-0.1.35-py3-none-any.whl.metadata (1.2 kB)
# Collecting llama-cloud-services==0.6.54 (from -r requirements.txt (line 133))
#   Downloading llama_cloud_services-0.6.54-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index==0.13.1 (from -r requirements.txt (line 135))
#   Downloading llama_index-0.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting llama-index-cli==0.5.0 (from -r requirements.txt (line 137))
#   Downloading llama_index_cli-0.5.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting llama-index-core==0.13.1 (from -r requirements.txt (line 139))
#   Downloading llama_index_core-0.13.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting llama-index-embeddings-nebius==0.4.0 (from -r requirements.txt (line 153))
#   Downloading llama_index_embeddings_nebius-0.4.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting llama-index-embeddings-openai==0.5.0 (from -r requirements.txt (line 155))
#   Downloading llama_index_embeddings_openai-0.5.0-py3-none-any.whl.metadata (400 bytes)
# Collecting llama-index-indices-managed-llama-cloud==0.9.1 (from -r requirements.txt (line 160))
#   Downloading llama_index_indices_managed_llama_cloud-0.9.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting llama-index-instrumentation==0.4.0 (from -r requirements.txt (line 162))
#   Downloading llama_index_instrumentation-0.4.0-py3-none-any.whl.metadata (252 bytes)
# Collecting llama-index-llms-nebius==0.2.0 (from -r requirements.txt (line 164))
#   Downloading llama_index_llms_nebius-0.2.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-index-llms-openai==0.5.3 (from -r requirements.txt (line 166))
#   Downloading llama_index_llms_openai-0.5.3-py3-none-any.whl.metadata (3.0 kB)
# Collecting llama-index-llms-openai-like==0.5.0 (from -r requirements.txt (line 171))
#   Downloading llama_index_llms_openai_like-0.5.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting llama-index-readers-file==0.5.1 (from -r requirements.txt (line 173))
#   Downloading llama_index_readers_file-0.5.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting llama-index-readers-llama-parse==0.5.0 (from -r requirements.txt (line 175))
#   Downloading llama_index_readers_llama_parse-0.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting llama-index-vector-stores-milvus==0.9.0 (from -r requirements.txt (line 177))
#   Downloading llama_index_vector_stores_milvus-0.9.0-py3-none-any.whl.metadata (373 bytes)
# Collecting llama-index-workflows==1.3.0 (from -r requirements.txt (line 179))
#   Downloading llama_index_workflows-1.3.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting llama-parse==0.6.54 (from -r requirements.txt (line 181))
#   Downloading llama_parse-0.6.54-py3-none-any.whl.metadata (6.6 kB)
# Collecting markupsafe==3.0.2 (from -r requirements.txt (line 183))
#   Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting marshmallow==3.26.1 (from -r requirements.txt (line 185))
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 187)) (0.1.7)
# Collecting milvus-lite==2.5.1 (from -r requirements.txt (line 191))
#   Downloading milvus_lite-2.5.1-py3-none-manylinux2014_x86_64.whl.metadata (10.0 kB)
# Collecting multidict==6.6.4 (from -r requirements.txt (line 193))
#   Downloading multidict-6.6.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting mypy-extensions==1.1.0 (from -r requirements.txt (line 197))
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 199)) (1.6.0)
# Requirement already satisfied: networkx==3.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 203)) (3.5)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 205)) (3.9.1)
# Collecting openai==1.99.9 (from -r requirements.txt (line 209))
#   Downloading openai-1.99.9-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: packaging==25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 214)) (25.0)
# Collecting pandas==2.2.3 (from -r requirements.txt (line 220))
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.8 MB/s eta 0:00:00
# Collecting parso==0.8.4 (from -r requirements.txt (line 224))
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: pexpect==4.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 226)) (4.9.0)
# Requirement already satisfied: pillow==11.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 228)) (11.3.0)
# Collecting platformdirs==4.3.8 (from -r requirements.txt (line 230))
#   Downloading platformdirs-4.3.8-py3-none-any.whl.metadata (12 kB)
# Collecting prompt-toolkit==3.0.51 (from -r requirements.txt (line 236))
#   Downloading prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: propcache==0.3.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 238)) (0.3.2)
# Collecting protobuf==6.31.1 (from -r requirements.txt (line 242))
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting psutil==7.0.0 (from -r requirements.txt (line 244))
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 246)) (0.7.0)
# Collecting pure-eval==0.2.3 (from -r requirements.txt (line 248))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic==2.11.7 (from -r requirements.txt (line 252))
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 261)) (2.33.2)
# Requirement already satisfied: pygments==2.19.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 263)) (2.19.2)
# Collecting pymilvus==2.6.0 (from -r requirements.txt (line 267))
#   Downloading pymilvus-2.6.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting pypdf==5.9.0 (from -r requirements.txt (line 271))
#   Downloading pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 273)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv==1.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 277)) (1.1.1)
# Requirement already satisfied: pytz==2025.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 282)) (2025.2)
# Collecting pyyaml==6.0.2 (from -r requirements.txt (line 286))
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pyzmq==27.0.1 (from -r requirements.txt (line 291))
#   Downloading pyzmq-27.0.1-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting regex==2025.7.34 (from -r requirements.txt (line 295))
#   Downloading regex-2025.7.34-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.32.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 300)) (2.32.4)
# Requirement already satisfied: safetensors==0.6.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 306)) (0.6.2)
# Collecting setuptools==80.9.0 (from -r requirements.txt (line 308))
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 312)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 314)) (1.3.1)
# Collecting soupsieve==2.7 (from -r requirements.txt (line 318))
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: sqlalchemy==2.0.43 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 320)) (2.0.43)
# Collecting stack-data==0.6.3 (from -r requirements.txt (line 322))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting striprtf==0.0.26 (from -r requirements.txt (line 324))
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting tenacity==9.1.2 (from -r requirements.txt (line 326))
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken==0.11.0 (from -r requirements.txt (line 330))
#   Downloading tiktoken-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting tokenizers==0.21.4 (from -r requirements.txt (line 332))
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting tornado==6.5.2 (from -r requirements.txt (line 334))
#   Downloading tornado-6.5.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 338)) (4.67.1)
# Collecting traitlets==5.14.3 (from -r requirements.txt (line 346))
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting transformers==4.55.2 (from -r requirements.txt (line 353))
#   Downloading transformers-4.55.2-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.0 MB/s eta 0:00:00
# Collecting typing-extensions==4.14.1 (from -r requirements.txt (line 355))
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting typing-inspect==0.9.0 (from -r requirements.txt (line 371))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting typing-inspection==0.4.1 (from -r requirements.txt (line 375))
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: tzdata==2025.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 377)) (2025.2)
# Collecting ujson==5.10.0 (from -r requirements.txt (line 379))
#   Downloading ujson-5.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: urllib3==2.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 381)) (2.5.0)
# Collecting wcwidth==0.2.13 (from -r requirements.txt (line 383))
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: wrapt==1.17.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 385)) (1.17.3)
# Collecting yarl==1.20.1 (from -r requirements.txt (line 389))
#   Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from llama-index-core==0.13.1->-r requirements.txt (line 139)) (2.0.2)
# Downloading aiohttp-3.12.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 54.1 MB/s eta 0:00:00
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 8.7 MB/s eta 0:00:00
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.8 MB/s eta 0:00:00
# Downloading banks-2.2.0-py3-none-any.whl (29 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 kB 14.1 MB/s eta 0:00:00
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 11.8 MB/s eta 0:00:00
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 8.4 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading debugpy-1.8.16-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 81.4 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.8/241.8 kB 18.2 MB/s eta 0:00:00
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 16.5 MB/s eta 0:00:00
# Downloading griffe-1.11.1-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 11.1 MB/s eta 0:00:00
# Downloading grpcio-1.74.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 104.1 MB/s eta 0:00:00
# Downloading hf_xet-1.1.7-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 36.9 MB/s eta 0:00:00
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 34.4 MB/s eta 0:00:00
# Downloading ipykernel-6.30.1-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 9.6 MB/s eta 0:00:00
# Downloading ipython-9.4.0-py3-none-any.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.0/611.0 kB 36.4 MB/s eta 0:00:00
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.8 MB/s eta 0:00:00
# Downloading jiter-0.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.0/352.0 kB 25.4 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 17.6 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 7.3 MB/s eta 0:00:00
# Downloading llama_cloud-0.1.35-py3-none-any.whl (303 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.3/303.3 kB 17.2 MB/s eta 0:00:00
# Downloading llama_cloud_services-0.6.54-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 4.9 MB/s eta 0:00:00
# Downloading llama_index-0.13.1-py3-none-any.whl (7.0 kB)
# Downloading llama_index_cli-0.5.0-py3-none-any.whl (28 kB)
# Downloading llama_index_core-0.13.1-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 83.4 MB/s eta 0:00:00
# Downloading llama_index_embeddings_nebius-0.4.0-py3-none-any.whl (4.4 kB)
# Downloading llama_index_embeddings_openai-0.5.0-py3-none-any.whl (7.0 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.9.1-py3-none-any.whl (16 kB)
# Downloading llama_index_instrumentation-0.4.0-py3-none-any.whl (14 kB)
# Downloading llama_index_llms_nebius-0.2.0-py3-none-any.whl (3.5 kB)
# Downloading llama_index_llms_openai-0.5.3-py3-none-any.whl (25 kB)
# Downloading llama_index_llms_openai_like-0.5.0-py3-none-any.whl (4.6 kB)
# Downloading llama_index_readers_file-0.5.1-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.7 MB/s eta 0:00:00
# Downloading llama_index_readers_llama_parse-0.5.0-py3-none-any.whl (3.2 kB)
# Downloading llama_index_vector_stores_milvus-0.9.0-py3-none-any.whl (15 kB)
# Downloading llama_index_workflows-1.3.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 3.2 MB/s eta 0:00:00
# Downloading llama_parse-0.6.54-py3-none-any.whl (4.9 kB)
# Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.1 MB/s eta 0:00:00
# Downloading milvus_lite-2.5.1-py3-none-manylinux2014_x86_64.whl (55.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 MB 19.8 MB/s eta 0:00:00
# Downloading multidict-6.6.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.1/256.1 kB 19.3 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading openai-1.99.9-py3-none-any.whl (786 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.8/786.8 kB 40.0 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 118.1 MB/s eta 0:00:00
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 kB 8.5 MB/s eta 0:00:00
# Downloading platformdirs-4.3.8-py3-none-any.whl (18 kB)
# Downloading prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.8/387.8 kB 26.4 MB/s eta 0:00:00
# Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 21.4 MB/s eta 0:00:00
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 19.0 MB/s eta 0:00:00
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 26.0 MB/s eta 0:00:00
# Downloading pymilvus-2.6.0-py3-none-any.whl (248 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.3/248.3 kB 17.5 MB/s eta 0:00:00
# Downloading pypdf-5.9.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 20.9 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 44.8 MB/s eta 0:00:00
# Downloading pyzmq-27.0.1-cp312-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (839 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 839.8/839.8 kB 41.8 MB/s eta 0:00:00
# Downloading regex-2025.7.34-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (801 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.9/801.9 kB 41.7 MB/s eta 0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.4 MB/s eta 0:00:00
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.6 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 97.6 MB/s eta 0:00:00
# Downloading tornado-6.5.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 29.0 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 6.8 MB/s eta 0:00:00
# Downloading transformers-4.55.2-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 120.0 MB/s eta 0:00:00
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 2.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading ujson-5.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 3.9 MB/s eta 0:00:00
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (355 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.6/355.6 kB 26.2 MB/s eta 0:00:00
# Installing collected packages: wcwidth, striprtf, pure-eval, filetype, dirtyjson, ujson, typing-extensions, traitlets, tornado, tenacity, soupsieve, setuptools, regex, pyzmq, pyyaml, pypdf, psutil, protobuf, prompt-toolkit, platformdirs, parso, mypy-extensions, multidict, milvus-lite, marshmallow, markupsafe, joblib, jiter, ipython-pygments-lexers, hf-xet, grpcio, fsspec, frozenlist, filelock, executing, deprecated, decorator, debugpy, comm, colorama, click, certifi, attrs, asttokens, yarl, typing-inspection, typing-inspect, stack-data, pandas, jedi, griffe, beautifulsoup4, anyio, aiosqlite, tiktoken, pymilvus, pydantic, jupyter-client, ipython, huggingface-hub, dataclasses-json, aiohttp, tokenizers, openai, llama-index-instrumentation, llama-cloud, ipykernel, banks, transformers, llama-index-workflows, llama-index-core, llama-index-vector-stores-milvus, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-cloud-services, llama-parse, llama-index-llms-openai-like, llama-index-embeddings-nebius, llama-index-cli, llama-index-readers-llama-parse, llama-index-llms-nebius, llama-index
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.14
#     Uninstalling wcwidth-0.2.14:
#       Successfully uninstalled wcwidth-0.2.14
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.4.2
#     Uninstalling tornado-6.4.2:
#       Successfully uninstalled tornado-6.4.2
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.8
#     Uninstalling soupsieve-2.8:
#       Successfully uninstalled soupsieve-2.8
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 26.2.1
#     Uninstalling pyzmq-26.2.1:
#       Successfully uninstalled pyzmq-26.2.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.3
#     Uninstalling PyYAML-6.0.3:
#       Successfully uninstalled PyYAML-6.0.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt_toolkit 3.0.52
#     Uninstalling prompt_toolkit-3.0.52:
#       Successfully uninstalled prompt_toolkit-3.0.52
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.5.0
#     Uninstalling platformdirs-4.5.0:
#       Successfully uninstalled platformdirs-4.5.0
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.5
#     Uninstalling parso-0.8.5:
#       Successfully uninstalled parso-0.8.5
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.7.0
#     Uninstalling multidict-6.7.0:
#       Successfully uninstalled multidict-6.7.0
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.2
#     Uninstalling joblib-1.5.2:
#       Successfully uninstalled joblib-1.5.2
#   Attempting uninstall: jiter
#     Found existing installation: jiter 0.11.0
#     Uninstalling jiter-0.11.0:
#       Successfully uninstalled jiter-0.11.0
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.1.10
#     Uninstalling hf-xet-1.1.10:
#       Successfully uninstalled hf-xet-1.1.10
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.75.1
#     Uninstalling grpcio-1.75.1:
#       Successfully uninstalled grpcio-1.75.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.8.0
#     Uninstalling frozenlist-1.8.0:
#       Successfully uninstalled frozenlist-1.8.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.20.0
#     Uninstalling filelock-3.20.0:
#       Successfully uninstalled filelock-3.20.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.15
#     Uninstalling debugpy-1.8.15:
#       Successfully uninstalled debugpy-1.8.15
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.10.5
#     Uninstalling certifi-2025.10.5:
#       Successfully uninstalled certifi-2025.10.5
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.4.0
#     Uninstalling attrs-25.4.0:
#       Successfully uninstalled attrs-25.4.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.22.0
#     Uninstalling yarl-1.22.0:
#       Successfully uninstalled yarl-1.22.0
#   Attempting uninstall: typing-inspection
#     Found existing installation: typing-inspection 0.4.2
#     Uninstalling typing-inspection-0.4.2:
#       Successfully uninstalled typing-inspection-0.4.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.13.5
#     Uninstalling beautifulsoup4-4.13.5:
#       Successfully uninstalled beautifulsoup4-4.13.5
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.11.0
#     Uninstalling anyio-4.11.0:
#       Successfully uninstalled anyio-4.11.0
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.12.0
#     Uninstalling tiktoken-0.12.0:
#       Successfully uninstalled tiktoken-0.12.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.10
#     Uninstalling pydantic-2.11.10:
#       Successfully uninstalled pydantic-2.11.10
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.4.9
#     Uninstalling jupyter_client-7.4.9:
#       Successfully uninstalled jupyter_client-7.4.9
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.35.3
#     Uninstalling huggingface-hub-0.35.3:
#       Successfully uninstalled huggingface-hub-0.35.3
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.13.0
#     Uninstalling aiohttp-3.13.0:
#       Successfully uninstalled aiohttp-3.13.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.0
#     Uninstalling transformers-4.57.0:
#       Successfully uninstalled transformers-4.57.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.30.1 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.4.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.7.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.7.0 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.31.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.31.1 which is incompatible.
# google-adk 1.14.1 requires tenacity<9.0.0,>=8.0.0, but you have tenacity 9.1.2 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# notebook 6.5.7 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.6.3 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.31.1 which is incompatible.
# Successfully installed aiohttp-3.12.15 aiosqlite-0.21.0 anyio-4.10.0 asttokens-3.0.0 attrs-25.3.0 banks-2.2.0 beautifulsoup4-4.13.4 certifi-2025.8.3 click-8.2.1 colorama-0.4.6 comm-0.2.3 dataclasses-json-0.6.7 debugpy-1.8.16 decorator-5.2.1 deprecated-1.2.18 dirtyjson-1.0.8 executing-2.2.0 filelock-3.18.0 filetype-1.2.0 frozenlist-1.7.0 fsspec-2025.7.0 griffe-1.11.1 grpcio-1.74.0 hf-xet-1.1.7 huggingface-hub-0.34.4 ipykernel-6.30.1 ipython-9.4.0 ipython-pygments-lexers-1.1.1 jedi-0.19.2 jiter-0.10.0 joblib-1.5.1 jupyter-client-8.6.3 llama-cloud-0.1.35 llama-cloud-services-0.6.54 llama-index-0.13.1 llama-index-cli-0.5.0 llama-index-core-0.13.1 llama-index-embeddings-nebius-0.4.0 llama-index-embeddings-openai-0.5.0 llama-index-indices-managed-llama-cloud-0.9.1 llama-index-instrumentation-0.4.0 llama-index-llms-nebius-0.2.0 llama-index-llms-openai-0.5.3 llama-index-llms-openai-like-0.5.0 llama-index-readers-file-0.5.1 llama-index-readers-llama-parse-0.5.0 llama-index-vector-stores-milvus-0.9.0 llama-index-workflows-1.3.0 llama-parse-0.6.54 markupsafe-3.0.2 marshmallow-3.26.1 milvus-lite-2.5.1 multidict-6.6.4 mypy-extensions-1.1.0 openai-1.99.9 pandas-2.2.3 parso-0.8.4 platformdirs-4.3.8 prompt-toolkit-3.0.51 protobuf-6.31.1 psutil-7.0.0 pure-eval-0.2.3 pydantic-2.11.7 pymilvus-2.6.0 pypdf-5.9.0 pyyaml-6.0.2 pyzmq-27.0.1 regex-2025.7.34 setuptools-80.9.0 soupsieve-2.7 stack-data-0.6.3 striprtf-0.0.26 tenacity-9.1.2 tiktoken-0.11.0 tokenizers-0.21.4 tornado-6.5.2 traitlets-5.14.3 transformers-4.55.2 typing-extensions-4.14.1 typing-inspect-0.9.0 typing-inspection-0.4.1 ujson-5.10.0 wcwidth-0.2.13 yarl-1.20.1

# %% [markdown]
# ## Step-2: Setup Embedding Model
#
# We have a choice of local embedding model (fast) or running it on the cloud
#
# If running locally:
# - choose smaller models
# - less accuracy but faster
#
# If running on the cloud
# - We can run large models (billions of params)

# %%
import os
from llama_index.core import Settings

# Option 1: Running embedding models on Nebius cloud
from llama_index.embeddings.nebius import NebiusEmbedding
EMBEDDING_MODEL = 'Qwen/Qwen3-Embedding-8B'  # 8B params
EMBEDDING_LENGTH = 4096  # Length of the embedding vector
Settings.embed_model = NebiusEmbedding(
                        model_name=EMBEDDING_MODEL,
                        embed_batch_size=50,  # Batch size for embedding (default is 10)
                        api_key=os.getenv("NEBIUS_API_KEY") # if not specfified here, it will get taken from env variable
                       )

## Option 2: Running embedding models locally
# from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
# Settings.embed_model = HuggingFaceEmbedding(
#     # model_name = 'sentence-transformers/all-MiniLM-L6-v2' # 23 M params
#     model_name = 'BAAI/bge-small-en-v1.5'  # 33M params
#     # model_name = 'Qwen/Qwen3-Embedding-0.6B'  # 600M params
#     # model_name = 'BAAI/bge-en-icl'  # 7B params
#     #model_name = 'intfloat/multilingual-e5-large-instruct'  # 560M params
# )

# %% [markdown]
# ## Step-3: Connect to Milvus

# %%
from pymilvus import MilvusClient

DB_URI = './rag.db'  # For embedded instance
COLLECTION_NAME = 'rag'

milvus_client = MilvusClient(DB_URI)
print ("✅ Connected to Milvus instance: ", DB_URI)
# Out:
# ✅ Connected to Milvus instance:  ./rag.db

# %%
# connect to vector db
from llama_index.core import VectorStoreIndex, StorageContext
from llama_index.vector_stores.milvus import MilvusVectorStore

vector_store = MilvusVectorStore(
    uri = DB_URI ,
    dim = EMBEDDING_LENGTH ,
    collection_name = COLLECTION_NAME,
    overwrite=False
)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

print ("✅ Connected Llama-index to Milvus instance: ", DB_URI )
# Out:
# ✅ Connected Llama-index to Milvus instance:  ./rag.db

# %% [markdown]
# ## Step-4: Load Document Index from DB

# %%
# %%time

from llama_index.core import VectorStoreIndex

index = VectorStoreIndex.from_vector_store(
    vector_store=vector_store, storage_context=storage_context)

print ("✅ Loaded index from vector db:", DB_URI )
# Out:
# ✅ Loaded index from vector db: ./rag.db
# CPU times: user 2.73 ms, sys: 0 ns, total: 2.73 ms
# Wall time: 2.67 ms

# %% [markdown]
# ## Step-5: Setup LLM

# %%
from llama_index.llms.nebius import NebiusLLM
from llama_index.core import Settings

Settings.llm = NebiusLLM(
                #model='openai/gpt-oss-120b',
                model='Qwen/Qwen3-30B-A3B',
                # model='deepseek-ai/DeepSeek-R1-0528',
                api_key=os.getenv("NEBIUS_API_KEY") # if not specfified, it will get taken from env variable
    )

# %% [markdown]
# ## Step-6: Query

# %%
query_engine = index.as_query_engine()
#res = query_engine.query("What is AstaP")
#print(res)

response_object = query_engine.query("What is AstaP")

# Print the response string (might be empty)
print("Final Answer:", str(response_object))

# 🔬 CRITICAL: Check what information was actually retrieved
print("\n--- Retrieved Source Nodes ---")
for i, node in enumerate(response_object.source_nodes):
    print(f"Node {i+1}:")
    print(f"Score (Similarity): {node.score}")
    print(f"Text Content: {node.node.text[:500]}...") # Print first 500 chars
    print("------")
# Out:
# Final Answer: Empty Response
#
# --- Retrieved Source Nodes ---

# %% [markdown]
# ## Making sure the model uses context
#
# Let's ask a generic factual question "When was the moon landing".
#
# Now the model should know this generic factual answer.
#
# But since we are querying documents, we want to the model to find answers from within the documents.
#
# It should come back with something like "provided context does not have information about moon landing"

# %%
query_engine = index.as_query_engine()
res = query_engine.query("When was the moon landing?")
print(res)
# Out:
# Empty Response
